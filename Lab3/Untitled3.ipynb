# %% [markdown]
# <a href="https://colab.research.google.com/github/jaroblesc/MetNumUN2022II/blob/main/Lab3/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![certificado 1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![certificado 2.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![certificado 3.jpg](data:image/jpeg;base64,...)
